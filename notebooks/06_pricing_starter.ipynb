# %% [markdown]
# <a href="https://colab.research.google.com/github/paolobalasso/DataScienceCourse/blob/main/notebooks/06_pricing_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 06 — Pricing Optimisation (starter)
#
# This is a **blank canvas**. Read `data/pricing_brief.md` and `data/pricing_rubric.md` before starting.
#
# Suggested section headers below. You are free to ignore them and structure your own analysis — the rubric grades the *output*, not the *path*.

# %% [markdown]
# ## 0. Setup

# %%
# %pip install -q pandas numpy matplotlib seaborn statsmodels scikit-learn
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
import statsmodels.formula.api as smf
plt.rcParams['figure.dpi']=110

# %% [markdown]
# ## 1. Load data

# %%
# In Colab, fetch from the public repo:
URL = 'https://raw.githubusercontent.com/paolobalasso/DataScienceCourse/main/data/retail_pricing_exercise.csv'
df = pd.read_csv(URL, parse_dates=['date'])
print(df.shape)
df.head()

# %% [markdown]
# ## 2. EDA
#
# _Your code here. Keep 2-3 plots maximum in the final deck._

# %%
# Your EDA

# %% [markdown]
# ## 3. Modelling
#
# _Defend every variable you include. Defend every variable you exclude._

# %%
# Your model

# %% [markdown]
# ## 4. Per-product elasticities

# %%
# Estimate one elasticity per product

# %% [markdown]
# ## 5. Scenario simulation
#
# For each product, simulate revenue at price × {0.9, 1.0, 1.1}.

# %%
# Your simulation

# %% [markdown]
# ## 6. Business recommendation
#
# _Write a 3-bullet recommendation here. Then copy-paste it into your slide deck._

# %% [markdown]
# ## 7. Caveats
#
# _What does your model NOT answer? Be honest._
